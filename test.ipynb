# %%
import os
import sys
sys.path.append(".")

# %%
from scripts.train import ImageColorizationTrainer

# %%
trainer = ImageColorizationTrainer("configs/test_options.json", train_dir="data/train2017", val_dir="data/val2017")
# Out:
# Filtering images: 100%|██████████| 500/500 [00:05<00:00, 89.53it/s]
# Skippped: gray: 30
# Filtering images: 100%|██████████| 500/500 [00:04<00:00, 107.17it/s]
# Skippped: gray: 28

# %%
trainer.train()
# Out:
# Epoch 1/5:  10%|█         | 3/30 [01:55<12:33, 27.91s/it, D_Loss=2.2014, G_Loss=16.0008]
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /Users/seungjunlee/Desktop/MLProjects/Image Colorization/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/seungjunlee/Desktop/MLProjects/Image Colorization/venv/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /Users/seungjunlee/Desktop/MLProjects/Image Colorization/venv/lib/python3.9/site-packages/lpips/weights/v0.1/alex.pth
# Epoch 1/5:  10%|█         | 3/30 [02:26<21:58, 48.83s/it, D_Loss=2.2014, G_Loss=16.0008]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 trainer.train()
#
# File ~/Desktop/MLProjects/Image Colorization/scripts/train.py:128, in ImageColorizationTrainer.train(self)
#     126 if (batch_idx % self.config['show_interval'] == 0 or batch_idx == total_batches - 1) and batch_idx != 0:
#     127     self._show_and_save_examples(gen_loss.item(), disc_loss.item(), epoch, batch_idx)
# --> 128     print(log_eval(self.generator, self.val_loader, 16, self.config['device']))
#     129     self.generator.train()
#     131 # Save the best model
#
# File ~/Desktop/MLProjects/Image Colorization/scripts/eval.py:68, in log_eval(generator, val_loader, num_batches, device)
#      65 fake_rgb = np.array(fake_rgb)
#      66 real_rgb = np.array(real_rgb)
# ---> 68 fake_rgb_tensor = torch.from_numpy(fake_rgb).permute(2, 0, 1).unsqueeze(0).to(device).float() / 255.0
#      69 real_rgb_tensor = torch.from_numpy(real_rgb).permute(2, 0, 1).unsqueeze(0).to(device).float() / 255.0
#      71 batch_lpips = lpips_model(fake_rgb_tensor, real_rgb_tensor).item()
#
# RuntimeError: permute(sparse_coo): number of dimensions in the tensor input does not match the length of the desired ordering of dimensions i.e. input.dim() = 4 is not equal to len(dims) = 3

# %% [markdown]
# Evaluation

# %%
from scripts.eval import eval_model

# %%
eval_model("configs/test_options.json",  
        "tests/BEST_GEN_epoch0_batch5679_6.508863925933838.pth", 
        "cpu",
        val_dir="data/val2017")
# Out:
# Filtering images: 100%|██████████| 500/500 [00:04<00:00, 103.22it/s]
# Skippped: gray: 28
# {'psnr': 20.06001396179199, 'ssim': 0.581209534464548}
